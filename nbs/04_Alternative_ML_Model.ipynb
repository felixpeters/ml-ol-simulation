# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !ls data
# Out:
# ls: data: No such file or directory

# %%
data = pd.read_csv("../data/alt_ml_agg_20200401-085720.csv")
data.head(10).transpose()
# Out:
#                             0        1        2        3        4        5  \
# config                 1.0000   2.0000   3.0000   4.0000   5.0000   6.0000
# belief_dims           30.0000  30.0000  30.0000  30.0000  30.0000  30.0000
# num_humans            50.0000  50.0000  50.0000  50.0000  50.0000  50.0000
# num_data_scientist     5.0000   5.0000   5.0000   5.0000   5.0000   5.0000
# p_1                    0.1000   0.1000   0.1000   0.1000   0.1000   0.1000
# p_2                    0.1000   0.1000   0.1000   0.5000   0.5000   0.5000
# p_h1                   0.1000   0.1000   0.1000   0.1000   0.1000   0.1000
# p_h2                   0.5000   0.5000   0.5000   0.5000   0.5000   0.5000
# p_ml                   0.2000   0.5000   0.8000   0.2000   0.5000   0.8000
# code_kl_max            0.9000   0.9000   0.9667   0.9166   0.9500   1.0000
# code_kl_last           0.9000   0.9000   0.9667   0.9166   0.9500   1.0000
# ...

# %%
plt.plot(data.human_kl_last, data.ds_kl_last, 'r.', scalex=False, scaley=False)

# %%
plt.plot(data.p_ml, data.ds_kl_last, 'r.', scalex=False, scaley=False)
