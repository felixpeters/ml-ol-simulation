# %%
# !ls data
# Out:
# analysis_agg_20200403-135718_code_kl_last.html
# analysis_agg_20200403-141520_code_kl_last.html
# analysis_agg_20200417-151616_code_kl_last.html
# analysis_ts_20200403-135718_code_kl.html
# analysis_ts_20200403-135718_human_kl_dissim.html
# analysis_ts_20200403-135718_human_kl_var.html
# analysis_ts_20200403-141520_code_kl.html
# analysis_ts_20200403-141520_human_kl_dissim.html
# analysis_ts_20200403-141520_human_kl_var.html
# analysis_ts_20200417-151616_code_kl.html
# analysis_ts_20200417-151616_human_kl_dissim.html
# analysis_ts_20200417-151616_human_kl_var.html
# basic_ml_agg_20200403-135718.csv
# basic_ml_agg_20200403-141520.csv
# basic_ml_agg_20200417-151616.csv
# basic_ml_ts_20200403-135718.csv
# basic_ml_ts_20200403-141520.csv
# basic_ml_ts_20200417-151616.csv
# ext_ml_agg_20200417-142015.csv
# ext_ml_ts_20200417-142015.csv
# r2_agg_20200917-101119.csv
# r2_ts_20200917-101119.csv

# %%
import pandas as pd

# %%
agg = pd.read_csv("data/r2_agg_20200917-101119.csv")
agg.head()
# Out:
#    config   m   n   j  p_1  p_2  p_3  q_h1  q_h2  q_ml  ...  human_kl_max  \
# 0       1  30  60  15  0.1  0.1  0.1   0.1   0.5   0.5  ...        0.6283
# 1       2  30  60  15  0.1  0.1  0.1   0.1   0.5   0.5  ...        0.5322
# 2       3  30  60  15  0.1  0.1  0.1   0.1   0.5   0.5  ...        0.6394
# 3       4  30  60  15  0.1  0.1  0.1   0.1   0.5   0.5  ...        0.5622
# 4       5  30  60  15  0.1  0.1  0.1   0.1   0.5   0.5  ...        0.6267
#
#    human_kl_last  human_kl_var_max  human_kl_var_last code_kl_std  \
# 0         0.6283            0.0091             0.0080         NaN
# 1         0.5111            0.0097             0.0075         NaN
# 2         0.6350            0.0083             0.0069         NaN
# 3         0.4633            0.0100             0.0048         NaN
# 4         0.6267            0.0097             0.0064         NaN
#
#   human_kl_std  human_kl_dissim_max  human_kl_dissim_last  data_qual_max  \
# ...

# %%
agg.describe()
# Out:
#            config      m      n      j         p_1         p_2         p_3  \
# count  256.000000  256.0  256.0  256.0  256.000000  256.000000  256.000000
# mean   128.500000   30.0   60.0   15.0    0.500000    0.500000    0.500000
# std     74.045031    0.0    0.0    0.0    0.400784    0.400784    0.400784
# min      1.000000   30.0   60.0   15.0    0.100000    0.100000    0.100000
# 25%     64.750000   30.0   60.0   15.0    0.100000    0.100000    0.100000
# 50%    128.500000   30.0   60.0   15.0    0.500000    0.500000    0.500000
# 75%    192.250000   30.0   60.0   15.0    0.900000    0.900000    0.900000
# max    256.000000   30.0   60.0   15.0    0.900000    0.900000    0.900000
#
#                q_h1   q_h2        q_ml  ...  human_kl_max  human_kl_last  \
# count  2.560000e+02  256.0  256.000000  ...    256.000000     256.000000
# mean   1.000000e-01    0.5    0.700000  ...      0.669470       0.615574
# ...
